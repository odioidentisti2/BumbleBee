# %%
# !pip install rdkit torch-geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.2/36.2 MB 65.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.7 MB/s eta 0:00:00
# ...

# %%
# !git clone --branch cross-validation https://github.com/odioidentisti2/BumbleBee
# %cd BumbleBee
# Out:
# Cloning into 'BumbleBee'...
# remote: Enumerating objects: 427, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 427 (delta 145), reused 150 (delta 81), pack-reused 207 (from 1)
# Receiving objects: 100% (427/427), 2.28 MiB | 6.88 MiB/s, done.
# Resolving deltas: 100% (269/269), done.
# /content/BumbleBee

# %%
# %run bumblebee.py
from google.colab import runtime
runtime.unassign()
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:f38de98d-9f0d-40de-9c92-bd5926ea4200

# %%
import sys
print(sys.version)
import torch
torch.__version__
torch.cuda.is_available()
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# '2.8.0+cu126'

# %%
from google.colab import runtime
runtime.unassign()
